# %%
import Util
from sklearn import preprocessing
import numpy as np
import librosa as lib
import librosa.display
import matplotlib.pyplot as plt

# %%
dataset_path = "../song_dataset"
data_path = "C:/Users/sarth/Desktop/ANN Project/data/artist20/mp3s-32k"

# %%
#Util.transform(data_path,dataset_path,"spectrogram")

# %%
X_train, y_train, S_train, X_val, y_val, S_val, X_test, y_test, S_test = Util.load_album(data_path,dataset_path)

# %%
plt.figure(figsize=(12, 5))
lib.display.specshow(X_train[0], sr=16000, x_axis='time', y_axis='mel')
plt.title('mel power spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()

# %%
frame_rate = 16000//512
frame_rate
# Out:
# 31

# %%
X_train,y_train,S_train = Util.slice_song(X_train,y_train,S_train, 32)
X_val,y_val,S_val = Util.slice_song(X_val,y_val,S_val, 32)
X_test,y_test,S_test = Util.slice_song(X_test,y_test,S_test, 32)

# %%
X_train[0].shape
# Out:
# (128, 32)

# %%
y_train, label, onehot = Util.encode(y_train)
y_val, label, onehot = Util.encode(y_val, label, onehot)
y_test, label, onehot = Util.encode(y_test, label, onehot)

# %%
X_train = X_train.reshape(X_train.shape + (1,))
X_val = X_val.reshape(X_val.shape + (1,))
X_test = X_test.reshape(X_test.shape + (1,))

# %%
X_train[0].shape
# Out:
# (128, 32, 1)
